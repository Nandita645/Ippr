# %% [markdown]
# <a href="https://colab.research.google.com/github/Nandita645/Ippr/blob/main/lab4/lab4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#basic list operation
fruits =[ "apple", "banana","orange","mango"]
#print ("original list :",fruits)
#print("first fruit:" fruits[0])
print("last fruit:", fruits[-1])
# Out:
# last fruit: mango

# %%
#basic list operation
fruits =[ "apple", "banana","orange","mango"]
#print ("original list :",fruits)
print("first fruit:", fruits[0])
#print("last fruit:", fruits[-1])
# Out:
# first fruit: apple

# %%
#basic list operation
fruits =[ "apple", "banana","orange","mango"]
print ("original list :",fruits)
#print("first fruit:", fruits[0])
#print("last fruit:", fruits[-1])
# Out:
# original list : ['apple', 'banana', 'orange', 'mango']

# %%
#adding items
fruits.append("grape")
print("After append:",fruits )
# Out:
# After append: ['apple', 'banana', 'orange', 'mango', 'grape']

# %%
#Removing items
fruits.remove("banana")
print("After remove:",fruits)
# Out:
# After remove: ['apple', 'orange', 'mango', 'grape']

# %%
#slicing
print("first 3 fruits:")
fruits[:3]
# Out:
# first 3 fruits:
# ['apple', 'orange', 'mango']

# %%
#list with numbers
numbers=[5,2,1,8,9,3]
print ("sum:",sum( numbers))
print ("max:",max (numbers))
print ("min:",min (numbers))
print ("sorted:",sorted (numbers))
print ("length:",len(numbers))
# Out:
# sum: 28
# max: 9
# min: 1
# sorted: [1, 2, 3, 5, 8, 9]
# length: 6

# %%
#list of movies
movies=["kanchana","aama","batman","spiderman"]
for movie in movies:
  print (movie)
# Out:
# kanchana
# aama
# batman
# spiderman

# %%
#finding averaage grades
grades=[85,10,67,89,30]
average =sum(grades)/len(grades)
print("average grade:",average)
# Out:
# average grade: 56.2

# %%
#Basic dictionary operation
student={
    "name":"jhon",
    "age":20,
    "program":"computer",
    "grade":"A"
}
print("student:",student)
print("name:",student["name"])
print("keys:",student.keys())
print("values:",student.values())
# Out:
# student: {'name': 'jhon', 'age': 20, 'program': 'computer', 'grade': 'A'}
# name: jhon
# keys: dict_keys(['name', 'age', 'program', 'grade'])
# values: dict_values(['jhon', 20, 'computer', 'A'])

# %%
#Adding or updating
student["city"]="kathmandu",
student["grade"]="A+"
print("updated:",student)
# Out:
# updated: {'name': 'jhon', 'age': 20, 'program': 'computer', 'grade': 'A+', 'city': ('kathmandu',)}

# %%
product= {
    "apple":0.99,
    "banana":0.44,
    "graps":2.33
}
#add a new product
product["orange"]=1.99
#update price
product["apple"]=3.00
#display all product
for products,price in product.items():
    print(f"{products}:${price}")
# Out:
# apple:$3.0
# banana:$0.44
# graps:$2.33
# orange:$1.99

# %%
#Tupples(immutable,ordered)
#create a tuple of days in a week
days =("sunday","monday","tuesday","wedness","thusday","friday","saturday")
print("weekend days:",days[5:7])
print("weekends:",days[:5])
# Out:
# weekend days: ('friday', 'saturday')
# weekends: ('sunday', 'monday', 'tuesday', 'wedness', 'thusday')

# %%
# Tuples (immutable, ordered)
# Create a tuple of days in a week

days = ("sunday", "monday", "tuesday", "wednesday", "thursday", "friday", "saturday")

# Weekend days using negative indexing
print("weekend days:", days[-2:])

# Weekdays using negative indexing
print("weekdays:", days[:-2])
# Out:
# weekend days: ('friday', 'saturday')
# weekdays: ('sunday', 'monday', 'tuesday', 'wednesday', 'thursday')

# %%
# Tuples (immutable, ordered)
# Create a tuple of days in a week

days = ("sunday", "monday", "tuesday", "wednesday", "thursday", "friday", "saturday")

# Weekend days using negative indexing
print("weekend days:", days[-1:])

# Weekdays using negative indexing
print("weekdays:", days[:-1])
# Out:
# weekend days: ('saturday',)
# weekdays: ('sunday', 'monday', 'tuesday', 'wednesday', 'thursday', 'friday')

# %%
# Tuples (immutable, ordered)
# Create a tuple of days in a week

days = ("sunday", "monday", "tuesday", "wednesday", "thursday", "friday", "saturday")

# Weekend days using negative indexing
print("weekend days:", days[-3:])

# Weekdays using negative indexing
print("weekdays:", days[:-2])
# Out:
# weekend days: ('thursday', 'friday', 'saturday')
# weekdays: ('sunday', 'monday', 'tuesday', 'wednesday', 'thursday')
